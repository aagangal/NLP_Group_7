# %%
import pandas as pd
import nltk
import re
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import numpy as np
import spacy
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\trevo\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
df = pd.read_csv(r'C:\Users\trevo\NLP\NLP_Group_7\LemmatizedDataset.csv')

analyzer = SentimentIntensityAnalyzer()

print(df.shape[0])

def get_sentiment_score(lyrics):
    sentiment = analyzer.polarity_scores(lyrics)
    sentiment_score = sentiment['compound']
    return sentiment_score

sentiment_scorelist = []
for i in range(df.shape[0]):
    sentiment_score = get_sentiment_score(df['Lemmatized_Lyrics'].iloc[i])
    sentiment_scorelist.append(sentiment_score)
df['Sentiment'] = sentiment_scorelist
df.head(11)
# Out:
# 38362
#     Unnamed: 0.1  Unnamed: 0               ALink               SName  \
# 0              0      139419      /foo-fighters/   Hey, Johnny Park!
# 1              1      290738              /mxpx/        Call In Sick
# 2              2      162905        /arch-enemy/   Despicable Heroes
# 3              3      281035         /the-maine/      Whoever She Is
# 4              4      253213              /a-ha/         Days On End
# 5              5      275382    /paul-mccartney/           Teddy Boy
# 6              6      164954      /king-diamond/  Sorry Dear (Outro)
# 7              7      314642       /david-bowie/    Fantastic Voyage
# 8              8      287943           /donovan/      Happiness Runs
# 9              9      131692  /heritage-singers/       I'll Fly Away
# 10            10      145261       /deep-purple/         It'll Be Me
#
#                                   SLink  \
# 0    /foo-fighters/hey-johnny-park.html
# 1               /mxpx/call-in-sick.html
# ...

# %%
df_artists = pd.read_csv(r'C:\Users\trevo\NLP\data\artists-data.csv')

# %%
df_artists = df_artists.rename(columns={'Link':'ALink'})

# %%
df_artists.head(10)
# Out:
#                 Artist                  Genres  Songs  Popularity  \
# 0        Ivete Sangalo     Pop; Axé; Romântico  313.0         4.4
# 1  Chiclete com Banana                     Axé  268.0         3.8
# 2            Banda Eva  Axé; Romântico; Reggae  215.0         2.3
# 3            É O Tchan                     Axé  129.0         1.6
# 4       Claudia Leitte     Pop; Axé; Romântico  167.0         1.5
# 5    Harmonia do Samba      Axé; Samba; Pagode  237.0         0.9
# 6             Ara Ketu                Axé; Pop  139.0         1.5
# 7      Daniela Mercury                MPB; Axé  230.0         1.4
# 8               Olodum                     Axé   74.0         1.3
# 9              Netinho                     Axé  204.0         2.0
#
#                    ALink
# 0        /ivete-sangalo/
# 1  /chiclete-com-banana/
# 2            /banda-eva/
# 3            /e-o-tchan/
# 4       /claudia-leitte/
# 5    /harmonia-do-samba/
# 6             /ara-ketu/
# 7      /daniela-mercury/
# ...

# %%
df.join(df_artists, on='ALink').select('Artist')

# %%
df_merge = pd.merge(df, df_artists[['ALink','Artist','Genres']], on='ALink', how='inner')

# %%
df_merge.head(50)
# Out:
#     Unnamed: 0.1  Unnamed: 0           ALink  \
# 0              0      139419  /foo-fighters/
# 1             46      139365  /foo-fighters/
# 2            315      139477  /foo-fighters/
# 3            319      139496  /foo-fighters/
# 4            835      139485  /foo-fighters/
# 5           1837      139500  /foo-fighters/
# 6           2478      139457  /foo-fighters/
# 7           2800      139494  /foo-fighters/
# 8           4356      139407  /foo-fighters/
# 9           5613      139454  /foo-fighters/
# 10          9963      139369  /foo-fighters/
# 11         10730      139420  /foo-fighters/
# 12         11349      139432  /foo-fighters/
# 13         11919      139340  /foo-fighters/
# 14         13823      139508  /foo-fighters/
# 15         14324      139465  /foo-fighters/
# 16         15477      139434  /foo-fighters/
# 17         18191      139459  /foo-fighters/
# 18         18612      139334  /foo-fighters/
# 19         20612      139490  /foo-fighters/
# ...

# %%
df_merge.to_csv(r'C:\Users\trevo\NLP\NLP_Group_7\FullyProcessedDataset.csv')

# %%
#Test
